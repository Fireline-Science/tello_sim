# %%
import tello_sim

# %%
drone = tello_sim.Simulator()
# Out:
# Hi! My name is TelloSim and I am your training drone.
# I help you try out your flight plan before sending it to a real Tello.
# I am now ready to take off. 🚁
# I am running your "command" command.

# %%
drone.takeoff()
# Out:
# My current altitude is 81 centimeters, so I can't takeoff again!

# %%
drone.forward("k")
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-5a8793d4e768> in <module>
# ----> 1 drone.forward("k")
#
# ~/Documents/tello_sim/tello_sim/simulator.py in forward(self, dist)
#     257         """
#     258         self.check_altitude()
# --> 259         self.check_int_param(dist)
#     260         print("My current bearing is {} degrees.".format(self.bearing))
#     261         new_loc = self.dist_bearing(orig=self.cur_loc, bearing=self.bearing, dist=dist)
#
# ~/Documents/tello_sim/tello_sim/simulator.py in check_int_param(param)
#      46     def check_int_param(param: int):
#      47         if type(param) != int:
# ---> 48             raise Exception("This command only accepts whole numbers without quotation marks.")
#      49         else:
#      50             pass
#
# ...

# %%
drone.cw(9)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "cw 9" command.
# My new bearing is 9 degrees.

# %%
drone.forward(100)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 9 degrees.
# I am running your "forward 100" command.

# %%
drone.takeoff()
# Out:
# My current altitude is 81 centimeters, so I can't takeoff again!

# %%
drone.flip("f")
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# I am running your "flip f" command.

# %%
"a" not in ["c", "f"]
# Out:
# True

# %%
drone.land()
# Out:
# Get ready for landing!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-71d556289be7> in <module>
# ----> 1 drone.land()
#
# ~/Documents/tello_sim/tello_sim/simulator.py in land(self)
#     149         """
#     150         print("Get ready for landing!")
# --> 151         self.check_altitude()
#     152         self.altitude = 0
#     153         self.send_command('land')
#
# ~/Documents/tello_sim/tello_sim/simulator.py in check_altitude(self)
#      70     def check_altitude(self):
#      71         if self.altitude == 0:
# ---> 72             raise Exception("I can't do that unless I take off first!")
#      73         else:
#      74             print("I am flying at {} centimeters above my takeoff altitude.".format(self.altitude))
#
# Exception: I can't do that unless I take off first!
