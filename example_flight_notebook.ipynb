# %%
import tello_sim

# %%
my_drone = tello_sim.Simulator()
# Out:
# Hi! My name is TelloSim and I am your training drone.
# I help you try out your flight plan before sending it to a real Tello.
# I am now ready to take off. 🚁
# I am running your "command" command.

# %%
my_drone.takeoff()
# Out:
# Get ready for takeoff!
# I am running your "takeoff" command.
# My estimated takeoff altitude is 81 centimeters

# %%
my_drone.forward(100)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "forward 100" command.

# %%
my_drone.flip("f")
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# I am running your "flip f" command.

# %%
my_drone.ccw(90)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "ccw 90" command.
# My current bearing is -90 degrees.

# %%
my_drone.forward(40)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is -90 degrees.
# I am running your "forward 40" command.

# %%
my_drone.up(25)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is -90 degrees.
# I am running your "up 25" command.

# %%
my_drone.land()
# Out:
# I am flying at 106 centimeters above my takeoff altitude.
# Get ready for landing!
# I am running your "land" command.
# Here are the graphs of your flight! I can't wait to try this for real.

# %%
my_drone.load_commands("commands.json")
# Out:
# Loading commands from commands.json
# Hi! My name is TelloSim and I am your training drone.
# I help you try out your flight plan before sending it to a real Tello.
# I am now ready to take off. 🚁
# I am running your "command" command.
# Get ready for takeoff!
# I am running your "takeoff" command.
# My estimated takeoff altitude is 81 centimeters
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "forward 100" command.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "cw 90" command.
# My new bearing is 90 degrees.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 90 degrees.
# I am running your "forward 100" command.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 90 degrees.
# I am running your "cw 90" command.
# My new bearing is 180 degrees.
# ...

# %%
my_drone.deploy()
# Out:
# Deploying your commands to a real Tello drone!
# Sending command: command
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 my_drone.deploy()
#
# File D:\Fireline Science\tello_sim\tello_sim\simulator.py:401, in Simulator.deploy(self)
#     396 print('Deploying your commands to a real Tello drone!')
#     398 if (self.driver_instance is None):
#     399     # Since the driver binds to a socket on instantiation, we can only
#     400     # keep a single driver instance open per session
# --> 401     self.driver_instance = Tello()
#     403 for command in self.command_log:
#     404     self.driver_instance.send_command(self.serialize_command(command))
#
# File D:\Fireline Science\tello_sim\venv\lib\site-packages\easytello\tello.py:31, in Tello.__init__(self, tello_ip, debug)
#      29 self.debug = debug
# ...
