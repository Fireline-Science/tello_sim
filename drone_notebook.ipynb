# %%
import tello_sim

# %%
drone = tello_sim.Simulator()

# %%
drone.takeoff()

# %%
drone.forward(35)

# %%
drone.down(25)

# %%
drone.cw(9)

# %%
drone.forward(100)

# %%
drone.takeoff()

# %%
drone.flip("f")

# %%
drone.forward(100)

# %%
drone.land()
